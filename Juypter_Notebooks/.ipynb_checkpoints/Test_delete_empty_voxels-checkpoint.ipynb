# %%
import h5py
import numpy as np
import os

# %%
def delete_empty_voxels(voxel_folder, num_layers_per_voxel):
    h5_list = os.listdir(voxel_folder)

    for h5_file in h5_list:
        with h5py.File(voxel_folder + '/' + h5_file,'a') as h5:
            key_list = h5.keys()
            for key in key_list:
                size_slice_cnt = 0
                for num_slice in range(num_layers_per_voxel):
                    size_slice = h5[key]['slice_{}'.format(num_slice)]['Area'].size #could be any other data column instead of 'Area' as well
                    size_slice_cnt += size_slice
                if size_slice_cnt == 0:
                    del h5[key]

# %%
delete_empty_voxels('/home/jan/Documents/Trainingsdaten/Voxel', 10)

# %%
h5_list = os.listdir('/home/jan/Documents/Trainingsdaten/Voxel')

# %%
for h5_file in h5_list:
    print(h5_file)
# Out:
# Voxel_layer_37.hdf5
# Voxel_layer_8.hdf5
# Voxel_layer_145.hdf5
# Voxel_layer_90.hdf5
# Voxel_layer_7.hdf5
# Voxel_layer_93.hdf5
# Voxel_layer_144.hdf5
# Voxel_layer_47.hdf5
# Voxel_layer_40.hdf5
# Voxel_layer_22.hdf5
# Voxel_layer_121.hdf5
# Voxel_layer_125.hdf5
# Voxel_layer_83.hdf5
# Voxel_layer_60.hdf5
# Voxel_layer_106.hdf5
# Voxel_layer_35.hdf5
# Voxel_layer_141.hdf5
# Voxel_layer_66.hdf5
# Voxel_layer_33.hdf5
# Voxel_layer_63.hdf5
# Voxel_layer_86.hdf5
# Voxel_layer_113.hdf5
# Voxel_layer_158.hdf5
# Voxel_layer_48.hdf5
# Voxel_layer_101.hdf5
# Voxel_layer_154.hdf5
# Voxel_layer_39.hdf5
# Voxel_layer_155.hdf5
# Voxel_layer_59.hdf5
# Voxel_layer_132.hdf5
# Voxel_layer_95.hdf5
# Voxel_layer_99.hdf5
# Voxel_layer_136.hdf5
# Voxel_layer_91.hdf5
# Voxel_layer_21.hdf5
# Voxel_layer_114.hdf5
# Voxel_layer_68.hdf5
# Voxel_layer_120.hdf5
# Voxel_layer_77.hdf5
# Voxel_layer_0.hdf5
# Voxel_layer_131.hdf5
# Voxel_layer_6.hdf5
# Voxel_layer_41.hdf5
# Voxel_layer_115.hdf5
# Voxel_layer_134.hdf5
# Voxel_layer_128.hdf5
# Voxel_layer_19.hdf5
# Voxel_layer_140.hdf5
# Voxel_layer_27.hdf5
# Voxel_layer_80.hdf5
# Voxel_layer_18.hdf5
# Voxel_layer_104.hdf5
# Voxel_layer_25.hdf5
# Voxel_layer_119.hdf5
# Voxel_layer_53.hdf5
# Voxel_layer_116.hdf5
# Voxel_layer_13.hdf5
# Voxel_layer_153.hdf5
# Voxel_layer_56.hdf5
# Voxel_layer_28.hdf5
# Voxel_layer_89.hdf5
# Voxel_layer_147.hdf5
# Voxel_layer_143.hdf5
# Voxel_layer_159.hdf5
# Voxel_layer_84.hdf5
# Voxel_layer_49.hdf5
# Voxel_layer_137.hdf5
# Voxel_layer_107.hdf5
# Voxel_layer_5.hdf5
# Voxel_layer_32.hdf5
# Voxel_layer_73.hdf5
# Voxel_layer_112.hdf5
# Voxel_layer_44.hdf5
# Voxel_layer_135.hdf5
# Voxel_layer_14.hdf5
# Voxel_layer_85.hdf5
# Voxel_layer_157.hdf5
# Voxel_layer_79.hdf5
# Voxel_layer_20.hdf5
# Voxel_layer_122.hdf5
# Voxel_layer_2.hdf5
# Voxel_layer_92.hdf5
# Voxel_layer_15.hdf5
# Voxel_layer_12.hdf5
# Voxel_layer_123.hdf5
# Voxel_layer_10.hdf5
# Voxel_layer_127.hdf5
# Voxel_layer_4.hdf5
# Voxel_layer_110.hdf5
# Voxel_layer_42.hdf5
# Voxel_layer_124.hdf5
# Voxel_layer_11.hdf5
# Voxel_layer_139.hdf5
# Voxel_layer_43.hdf5
# Voxel_layer_74.hdf5
# Voxel_layer_81.hdf5
# Voxel_layer_58.hdf5
# Voxel_layer_152.hdf5
# Voxel_layer_9.hdf5
# Voxel_layer_75.hdf5
# Voxel_layer_142.hdf5
# Voxel_layer_17.hdf5
# Voxel_layer_46.hdf5
# Voxel_layer_156.hdf5
# Voxel_layer_117.hdf5
# Voxel_layer_87.hdf5
# Voxel_layer_31.hdf5
# Voxel_layer_1.hdf5
# Voxel_layer_71.hdf5
# Voxel_layer_36.hdf5
# Voxel_layer_70.hdf5
# Voxel_layer_126.hdf5
# Voxel_layer_23.hdf5
# Voxel_layer_150.hdf5
# Voxel_layer_151.hdf5
# Voxel_layer_148.hdf5
# Voxel_layer_62.hdf5
# Voxel_layer_129.hdf5
# Voxel_layer_29.hdf5
# Voxel_layer_64.hdf5
# Voxel_layer_51.hdf5
# Voxel_layer_61.hdf5
# Voxel_layer_52.hdf5
# Voxel_layer_138.hdf5
# Voxel_layer_30.hdf5
# Voxel_layer_78.hdf5
# Voxel_layer_149.hdf5
# Voxel_layer_146.hdf5
# Voxel_layer_94.hdf5
# Voxel_layer_118.hdf5
# Voxel_layer_54.hdf5
# Voxel_layer_111.hdf5
# Voxel_layer_105.hdf5
# Voxel_layer_57.hdf5
# Voxel_layer_88.hdf5
# Voxel_layer_98.hdf5
# Voxel_layer_102.hdf5
# Voxel_layer_24.hdf5
# Voxel_layer_97.hdf5
# Voxel_layer_76.hdf5
# Voxel_layer_50.hdf5
# Voxel_layer_96.hdf5
# Voxel_layer_82.hdf5
# Voxel_layer_108.hdf5
# Voxel_layer_55.hdf5
# Voxel_layer_100.hdf5
# Voxel_layer_67.hdf5
# Voxel_layer_45.hdf5
# Voxel_layer_3.hdf5
# Voxel_layer_130.hdf5
# Voxel_layer_38.hdf5
# Voxel_layer_69.hdf5
# Voxel_layer_133.hdf5
# Voxel_layer_72.hdf5
# Voxel_layer_16.hdf5
# Voxel_layer_109.hdf5
# Voxel_layer_65.hdf5
# Voxel_layer_34.hdf5
# Voxel_layer_103.hdf5
# Voxel_layer_26.hdf5
