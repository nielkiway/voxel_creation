# %%
import pandas as pd
import numpy as np
import h5py
import time 
import matplotlib.pyplot as plt

# %%
def get_2D_data_from_h5_filtered(h5_path, part_name, Slice_name, mode):
    #Step 1: getting the data from the h5
    start_time = time.time()
    with h5py.File(h5_path,'r') as h5:
        X_Axis = h5[part_name][Slice_name]['X-Axis']
        Y_Axis = h5[part_name][Slice_name]['Y-Axis']
        Area = h5[part_name][Slice_name]['Area']
        Intensity = h5[part_name][Slice_name]['Intensity']

        X_Axis_size = X_Axis.size
        Y_Axis_size = Y_Axis.size
        Area_size = Area.size
        Intensity_size = Intensity.size

        #if dimensions aren't equal the following code block is entered
        if not X_Axis_size == Y_Axis_size == Area_size == Intensity_size:

            #determine the lowest value among the different sizes
            size_arr = np.array([X_Axis_size, Y_Axis_size, Area_size, Intensity_size])
            min_size = size_arr.min()

            if X_Axis_size != min_size:
                diff_size_x = X_Axis_size - min_size #calculating the difference between the actual value and the minimum and substracting it from the array
                X_Axis_new = np.delete(X_Axis, -diff_size_x)
                X_Axis = X_Axis_new
                X_Axis_size = X_Axis.size

            if Y_Axis_size != min_size:
                diff_size_y = Y_Axis_size - min_size
                Y_Axis_new = np.delete(Y_Axis, -diff_size_y)
                Y_Axis = Y_Axis_new
                Y_Axis_size = Y_Axis.size

            if Area_size != min_size:
                diff_size_area = Area_size - min_size
                Area_new = np.delete(Area, -diff_size_area)
                Area = Area_new
                Area_size = Area.size

            if Intensity_size != min_size:
                diff_size_intensity = Intensity_size - min_size
                Intensity_new = np.delete(Intensity, -diff_size_intensity)
                Intensity = Intensity_new
                Intensity_size = Intensity.size


        #by reducing all the dimensions to the minimum equal dimensions are guaranteed
        #there is a risk of deleting more than just one datapoint without noticing -> maybe add an alert after more than 5(?) while iterations
        help_arr = np.column_stack((X_Axis, Y_Axis, Area, Intensity))
        df_raw = pd.DataFrame(help_arr, columns=['x','y','area','intensity'])

    #Step 2: change floats to ints and remove duplicates
    df_int = df_raw.astype(int).drop_duplicates()

    #remove all rows with 0 for area and intensity
    df_int = df_int.loc[(df_int['area'] != 0) & (df_int['intensity'] != 0)]


    #Step 3: Get a df with all the rows where a certain x,y combination occurs multiple times
    df_multi_xy = df_int[df_int.duplicated(['x','y'], keep = False)]

    #Step 4: get a new df out of df_multi_xy with x,y and mean/max of area and intensity for all x,y occurences
    df_compact = pd.DataFrame(columns=['x','y','area','intensity']) #initialize df_compact

    print("vor iterieren %s seconds ---" % (time.time() - start_time))
    for ind in range (df_multi_xy.shape[0]):
        if mode == 'mean':
            area_mean = df_multi_xy.loc[(df_multi_xy['x']== df_multi_xy.iloc[ind]['x']) & (df_multi_xy['y'] == df_multi_xy.iloc[ind]['y'])]['area'].mean().astype(int)
            intensity_mean = df_multi_xy.loc[(df_multi_xy['x']== df_multi_xy.iloc[ind]['x']) & (df_multi_xy['y'] == df_multi_xy.iloc[ind]['y'])]['intensity'].mean().astype(int)
            df_compact = df_compact.append({'x': df_multi_xy.iloc[ind]['x'], 'y':df_multi_xy.iloc[ind]['y'], 'area':area_mean , 'intensity':intensity_mean}, ignore_index=True)
        if mode == 'max':
            area_max = df_multi_xy.loc[(df_multi_xy['x']== df_multi_xy.iloc[ind]['x']) & (df_multi_xy['y'] == df_multi_xy.iloc[ind]['y'])]['area'].max().astype(int)
            intensity_max = df_multi_xy.loc[(df_multi_xy['x']== df_multi_xy.iloc[ind]['x']) & (df_multi_xy['y'] == df_multi_xy.iloc[ind]['y'])]['intensity'].max().astype(int)
            df_compact = df_compact.append({'x': df_multi_xy.iloc[ind]['x'], 'y':df_multi_xy.iloc[ind]['y'], 'area':area_max , 'intensity':intensity_max}, ignore_index=True)
    df_compact = df_compact.drop_duplicates()

    #Step 5: remove df_multi_xy from df_int and append df_compact
    df_multi_xy_removed = df_int.drop(df_int[df_int.duplicated(['x','y'], keep = False)].index)

    df_final = df_multi_xy_removed.append(df_compact)
    print("df creation took %s seconds ---" % (time.time() - start_time))
    return (df_final)

# %%
df_undocked = get_2D_data_from_h5_filtered('/home/jan/Documents/CodeTDMStoHDF/Ausgangsdaten/examplerRun.h5', '0_00003_Canti3_cls', 'Slice00003', 'mean')
# Out:
# vor iterieren 0.06362318992614746 seconds ---
# df creation took 84.35257935523987 seconds ---

# %%
def get_true_min_maxX (h5_path, part_name, max_slice_number):

    minX = []
    maxX = []
    for num_slice in range(max_slice_number):
        with h5py.File(h5_path,'r') as h5:
            X_Axis = h5[part_name]['Slice'+str("{:05d}".format(num_slice+1))]['X-Axis']
            x_axis_array = np.array(X_Axis)
            minX.append(x_axis_array.min())
            maxX.append(x_axis_array.max())
    minX_array = np.asarray(minX)
    maxX_array = np.asarray(maxX)
    return minX_array.min(), maxX_array.max()

# %%
def get_true_min_maxY (h5_path, part_name, max_slice_number):

    minY = []
    maxY = []
    for num_slice in range(max_slice_number):
        with h5py.File(h5_path,'r') as h5:
            Y_Axis = h5[part_name]['Slice'+str("{:05d}".format(num_slice+1))]['Y-Axis']
            y_axis_array = np.array(Y_Axis)
            minY.append(y_axis_array.min())
            maxY.append(y_axis_array.max())
    minY_array = np.asarray(minY)
    maxY_array = np.asarray(maxY)
    return minY_array.min(), maxY_array.max()

# %%
minX = get_true_min_maxX('/home/jan/Documents/CodeTDMStoHDF/Ausgangsdaten/examplerRun.h5', '0_00003_Canti3_cls', 142)[0]
maxX = get_true_min_maxX('/home/jan/Documents/CodeTDMStoHDF/Ausgangsdaten/examplerRun.h5', '0_00003_Canti3_cls', 142)[1]
minY = get_true_min_maxY('/home/jan/Documents/CodeTDMStoHDF/Ausgangsdaten/examplerRun.h5', '0_00003_Canti3_cls', 142)[0]
maxY = get_true_min_maxY('/home/jan/Documents/CodeTDMStoHDF/Ausgangsdaten/examplerRun.h5', '0_00003_Canti3_cls', 142)[1]

# %%
length_x = int(maxX-minX)

# %%
length_y = int(maxY-minY)

# %%
def dock_df_to_zero(df, minX, minY):
    if minX >= 0 and minY >=0:
        df['x'] = df['x'] - minX
        df['y'] = df['y'] - minY
    elif minX < 0 and minY <0:
        df['x'] = df['x'] + abs(minX)
        df['y'] = df['y'] + abs(minY)
    elif minX >= 0 and minY <0:
        df['x'] = df['x'] - minX
        df['y'] = df['y'] + abs(minY)
    elif minX < 0 and min >= 0:
        df['x'] = df['x'] + abs(minX)
        df['y'] = df['y'] - minY
    return df

# %%
df = dock_df_to_zero(df_undocked, minX, minY)

# %%
#creating an empty dataframe with all possible combinations of x and y values

# %%
x_Axis = np.repeat(np.arange(0,length_x+1,1),length_y+1)
y_Axis = np.tile(np.arange(0,length_y+1,1),length_x+1)

# %%
x_Axis
# Out:
# array([   0,    0,    0, ..., 4946, 4946, 4946])

# %%
y_Axis.size
# Out:
# 44508159

# %%
#creating a dataframe to be filled with x_Axis, y_Axis data and zeros for intensity and area

# %%
array_0s  = np.zeros((x_Axis.size,), dtype=int)

# %%
help_arr = np.column_stack((x_Axis, y_Axis, array_0s, array_0s))
df_0s= pd.DataFrame(help_arr, columns=['x','y','area','intensity'])

# %%
df_0s = 0

# %%
df
# Out:
#           x     y area intensity
# 971    3519  3578  203       545
# 973    3535  3578  248       520
# 974    3541  3578  221       521
# 975    3551  3578  194      1017
# 976    3557  3578  265       932
# ...     ...   ...  ...       ...
# 17075  3528  8817  298       530
# 17082  3649  8977  347       577
# 17088  3528  8897  240       504
# 17095  3569  8977  183       474
# 17102  3528  8977  192       559
#
# [63728 rows x 4 columns]

# %%
df_with_dupl = df_0s.append(df)

# %%
df_with_dupl = 0

# %%
df_wo_dupl = df_with_dupl.drop_duplicates(['x','y'], keep = 'last')

# %%
df_wo_dupl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44508159 entries, 0 to 17102
# Data columns (total 4 columns):
# x            object
# y            object
# area         object
# intensity    object
# dtypes: object(4)
# memory usage: 1.7+ GB

# %%
df_final = df_wo_dupl.sort_values(by=['x', 'y']).reset_index(drop = True)

# %%
df_final.tail()
# Out:
#              x     y area intensity
# 44508154  4946  8992    0         0
# 44508155  4946  8993  236       531
# 44508156  4946  8994    0         0
# 44508157  4946  8995  212       537
# 44508158  4946  8996  232       555

# %%
df_ex_1 = pd.DataFrame({"x": [5,6,7,8],
                        "y": [1,1,1,1],
                        "area": [10, 13, 21, 10],
                        "intensity": [12,43,34,12]})

# %%
df_ex_1
# Out:
#    x  y  area  intensity
# 0  5  1    10         12
# 1  6  1    13         43
# 2  7  1    21         34
# 3  8  1    10         12

# %%
df_ex_2 = pd.DataFrame({"x": [1,2,3,4,5,6,7,8],
                        "y": [1,1,1,1,1,1,1,1],
                        "area": [0,0,0,0,0,0,0,0],
                        "intensity": [0,0,0,0,0,0,0,0]})

# %%
df_ex_2
# Out:
#    x  y  area  intensity
# 0  1  1     0          0
# 1  2  1     0          0
# 2  3  1     0          0
# 3  4  1     0          0
# 4  5  1     0          0
# 5  6  1     0          0
# 6  7  1     0          0
# 7  8  1     0          0

# %%
df_ex_3 = df_ex_2.append(df_ex_1)

# %%
df_ex_4 = df_ex_3.drop_duplicates(['x','y'], keep = 'last')

# %%
df_ex_5 = df_ex_4.sort_values(by=['area', 'intensity']).reset_index(drop = True)

# %%
df_ex_5
# Out:
#    x  y  area  intensity
# 0  1  1     0          0
# 1  2  1     0          0
# 2  3  1     0          0
# 3  4  1     0          0
# 4  5  1    10         12
# 5  8  1    10         12
# 6  6  1    13         43
# 7  7  1    21         34

# %%
#practicing the creation of a new df out of the old one based on conditions

# %%
result = pd.concat([df_ex_5.iloc[:2],  df_ex_5.iloc[[2,4]]])

# %%
result
# Out:
#    x  y  area  intensity
# 0  1  1     0          0
# 1  2  1     0          0
# 2  3  1     0          0
# 4  5  1    10         12

# %%
voxel_size = 20

# %%
start_time = time.time()
voxel_df = df_final[(df_final['x'] > 50 ) & (df_final['x'] < 300 ) & (df_final['y'] < 300) & (df_final['y'] > 50)]
print("voxel filling took %s seconds ---" % (time.time() - start_time))                                              
#dfObj[(dfObj['x'] < 20) & (dfObj['y'] < 20) ]
# Out:
# voxel filling took 6.743647575378418 seconds ---

# %%
voxel_df['y'].values.astype(int)
# Out:
# array([ 51,  52,  53, ..., 297, 298, 299])

# %%
voxel_hdf = h5py.File('/home/jan/Documents/Voxel_Erstellung/HDFs/voxel_new_filling_method.hdf5', "w")
voxel_hdf.close()

# %%
voxel_size = 100
np.repeat(np.arange(0,voxel_size,1),voxel_size)
# Out:
# array([ 0,  0,  0, ..., 99, 99, 99])

# %%
num_voxels_x = 20
num_voxels_y = 20
voxel_size = 100
num_z = 1

for n_vox_y_init in range(num_voxels_y): #iterating over number of voxels in y-direction
    for n_vox_x_init in range(num_voxels_x):#iterating over number of voxels in x-direction
        #print('n_vox_x_init: '+ str(n_vox_x_init))
            start_time = time.time()
            voxel_df = df_final[(df_final['x'] >= voxel_size*num_voxels_x ) & (df_final['x'] < voxel_size*(num_voxels_x+1)) & (df_final['y'] >= voxel_size*num_voxels_y) & (df_final['y'] < voxel_size*(num_voxels_y+1))]
            
            with h5py.File('/home/jan/Documents/Voxel_Erstellung/HDFs/voxel_new_filling_method.hdf5', "a") as voxel_hdf:
                #creating a voxel with the numbers of voxels in both direction in its name and filling it with data
                #if group is already existing don't create a new group
                if 'voxel_{}_{}_{}'.format(n_vox_x_init,n_vox_y_init, num_z) not in voxel_hdf:
                    voxel_hdf.create_group('voxel_{}_{}_{}'.format(n_vox_x_init,n_vox_y_init,num_z))
                #voxel_hdf['voxel_{}_{}_{}'.format(n_vox_x_init,n_vox_y_init,num_z)].create_group('slice_1') #-num_z*num_slices_vox wegen
                voxel_hdf['voxel_{}_{}_{}'.format(n_vox_x_init,n_vox_y_init,num_z)].create_dataset('X-Axis',data = np.repeat(np.arange(0,voxel_size,1),voxel_size))
                voxel_hdf['voxel_{}_{}_{}'.format(n_vox_x_init,n_vox_y_init,num_z)].create_dataset('Y-Axis',data = np.tile(np.arange(0,voxel_size,1),voxel_size))
                voxel_hdf['voxel_{}_{}_{}'.format(n_vox_x_init,n_vox_y_init,num_z)].create_dataset('Area', data = voxel_df['area'].values.astype(int))
                voxel_hdf['voxel_{}_{}_{}'.format(n_vox_x_init,n_vox_y_init,num_z)].create_dataset('Intensity', data = voxel_df['intensity'].values.astype(int))
           
            print("voxel filling took %s seconds ---" % (time.time() - start_time))  
            print('filling voxel_{}_{}_{}'.format(n_vox_x_init,n_vox_y_init, num_z))
# Out:
# voxel filling took 6.828061580657959 seconds ---
# filling voxel_0_0_1
# voxel filling took 6.7900002002716064 seconds ---
# filling voxel_1_0_1
# voxel filling took 6.729922771453857 seconds ---
# filling voxel_2_0_1
# voxel filling took 6.728012561798096 seconds ---
# filling voxel_3_0_1
# voxel filling took 6.7176947593688965 seconds ---
# filling voxel_4_0_1
# voxel filling took 6.805440902709961 seconds ---
# filling voxel_5_0_1
# voxel filling took 6.812559604644775 seconds ---
# filling voxel_6_0_1
# voxel filling took 6.849747657775879 seconds ---
# filling voxel_7_0_1
# voxel filling took 6.8462207317352295 seconds ---
# filling voxel_8_0_1
# voxel filling took 6.822354793548584 seconds ---
# filling voxel_9_0_1
# voxel filling took 6.875306844711304 seconds ---
# filling voxel_10_0_1
# voxel filling took 7.002715110778809 seconds ---
# filling voxel_11_0_1
# voxel filling took 7.098147392272949 seconds ---
# filling voxel_12_0_1
# voxel filling took 7.107427597045898 seconds ---
# filling voxel_13_0_1
# voxel filling took 8.243619918823242 seconds ---
# filling voxel_14_0_1
# voxel filling took 7.868117332458496 seconds ---
# filling voxel_15_0_1
# voxel filling took 9.136793375015259 seconds ---
# filling voxel_16_0_1
# voxel filling took 6.790802001953125 seconds ---
# filling voxel_17_0_1
# voxel filling took 6.649431228637695 seconds ---
# filling voxel_18_0_1
# voxel filling took 6.429321527481079 seconds ---
# filling voxel_19_0_1
# voxel filling took 6.453809499740601 seconds ---
# filling voxel_0_1_1
# voxel filling took 6.434548377990723 seconds ---
# filling voxel_1_1_1
# voxel filling took 6.587445020675659 seconds ---
# filling voxel_2_1_1
# voxel filling took 6.656110525131226 seconds ---
# filling voxel_3_1_1
# voxel filling took 6.498600721359253 seconds ---
# filling voxel_4_1_1
# voxel filling took 6.349283456802368 seconds ---
# filling voxel_5_1_1
# voxel filling took 6.244492530822754 seconds ---
# filling voxel_6_1_1
# voxel filling took 6.168132543563843 seconds ---
# filling voxel_7_1_1
# voxel filling took 6.1909403800964355 seconds ---
# filling voxel_8_1_1
# voxel filling took 6.091536283493042 seconds ---
# filling voxel_9_1_1
# voxel filling took 6.063382863998413 seconds ---
# filling voxel_10_1_1
# voxel filling took 6.025873184204102 seconds ---
# filling voxel_11_1_1
# voxel filling took 6.05376124382019 seconds ---
# filling voxel_12_1_1
# voxel filling took 6.139622211456299 seconds ---
# filling voxel_13_1_1
# voxel filling took 6.202462911605835 seconds ---
# filling voxel_14_1_1
# voxel filling took 6.2916059494018555 seconds ---
# filling voxel_15_1_1
# voxel filling took 6.355643272399902 seconds ---
# filling voxel_16_1_1
# voxel filling took 6.3614280223846436 seconds ---
# filling voxel_17_1_1
# voxel filling took 6.412864923477173 seconds ---
# filling voxel_18_1_1
# voxel filling took 6.429445028305054 seconds ---
# filling voxel_19_1_1
# voxel filling took 6.285268068313599 seconds ---
# filling voxel_0_2_1
# voxel filling took 6.2196738719940186 seconds ---
# filling voxel_1_2_1
# voxel filling took 6.180768251419067 seconds ---
# filling voxel_2_2_1
# voxel filling took 6.175941467285156 seconds ---
# filling voxel_3_2_1
# voxel filling took 6.207571744918823 seconds ---
# filling voxel_4_2_1
# voxel filling took 6.244843244552612 seconds ---
# filling voxel_5_2_1
# voxel filling took 6.308049201965332 seconds ---
# filling voxel_6_2_1
# voxel filling took 6.3715996742248535 seconds ---
# filling voxel_7_2_1
# voxel filling took 6.313575029373169 seconds ---
# filling voxel_8_2_1
# voxel filling took 6.332532167434692 seconds ---
# filling voxel_9_2_1
# voxel filling took 6.398796081542969 seconds ---
# filling voxel_10_2_1
# voxel filling took 6.431306600570679 seconds ---
# filling voxel_11_2_1
# voxel filling took 6.411306619644165 seconds ---
# filling voxel_12_2_1
# voxel filling took 7.463454008102417 seconds ---
# filling voxel_13_2_1
# voxel filling took 6.503581523895264 seconds ---
# filling voxel_14_2_1
# voxel filling took 6.545309543609619 seconds ---
# filling voxel_15_2_1
# voxel filling took 6.3290321826934814 seconds ---
# filling voxel_16_2_1
# voxel filling took 6.232652902603149 seconds ---
# filling voxel_17_2_1
# voxel filling took 6.2948384284973145 seconds ---
# filling voxel_18_2_1
# voxel filling took 6.349378824234009 seconds ---
# filling voxel_19_2_1
# voxel filling took 6.428560495376587 seconds ---
# filling voxel_0_3_1
# voxel filling took 6.478006601333618 seconds ---
# filling voxel_1_3_1
# voxel filling took 6.504424810409546 seconds ---
# filling voxel_2_3_1
# voxel filling took 6.4374306201934814 seconds ---
# filling voxel_3_3_1
# voxel filling took 6.356502056121826 seconds ---
# filling voxel_4_3_1
# voxel filling took 6.402533769607544 seconds ---
# filling voxel_5_3_1
# voxel filling took 6.62980055809021 seconds ---
# filling voxel_6_3_1
# voxel filling took 6.714062929153442 seconds ---
# filling voxel_7_3_1
# voxel filling took 8.122946977615356 seconds ---
# filling voxel_8_3_1
# voxel filling took 9.302913188934326 seconds ---
# filling voxel_9_3_1
# voxel filling took 7.284547805786133 seconds ---
# filling voxel_10_3_1
# voxel filling took 6.920087575912476 seconds ---
# filling voxel_11_3_1
# voxel filling took 6.711531639099121 seconds ---
# filling voxel_12_3_1
# voxel filling took 6.610724687576294 seconds ---
# filling voxel_13_3_1
# voxel filling took 6.595911979675293 seconds ---
# filling voxel_14_3_1
# voxel filling took 6.485597372055054 seconds ---
# filling voxel_15_3_1
# voxel filling took 6.465261936187744 seconds ---
# filling voxel_16_3_1
# voxel filling took 6.4219934940338135 seconds ---
# filling voxel_17_3_1
# voxel filling took 6.393265962600708 seconds ---
# filling voxel_18_3_1
# voxel filling took 6.4041454792022705 seconds ---
# filling voxel_19_3_1
# voxel filling took 6.45073676109314 seconds ---
# filling voxel_0_4_1
# voxel filling took 6.562626123428345 seconds ---
# filling voxel_1_4_1
# voxel filling took 6.633115291595459 seconds ---
# filling voxel_2_4_1
# voxel filling took 6.670744180679321 seconds ---
# filling voxel_3_4_1
# voxel filling took 6.7228991985321045 seconds ---
# filling voxel_4_4_1
# voxel filling took 6.701764106750488 seconds ---
# filling voxel_5_4_1
# voxel filling took 6.592631101608276 seconds ---
# filling voxel_6_4_1
# voxel filling took 6.587892293930054 seconds ---
# filling voxel_7_4_1
# voxel filling took 6.652223110198975 seconds ---
# filling voxel_8_4_1
# voxel filling took 6.739208459854126 seconds ---
# filling voxel_9_4_1
# voxel filling took 6.787167549133301 seconds ---
# filling voxel_10_4_1
# voxel filling took 6.748027563095093 seconds ---
# filling voxel_11_4_1
# voxel filling took 6.8074986934661865 seconds ---
# filling voxel_12_4_1
# voxel filling took 6.668040990829468 seconds ---
# filling voxel_13_4_1
# voxel filling took 6.557741165161133 seconds ---
# filling voxel_14_4_1
# voxel filling took 6.490853309631348 seconds ---
# filling voxel_15_4_1
# voxel filling took 6.583367586135864 seconds ---
# filling voxel_16_4_1
# voxel filling took 6.668859243392944 seconds ---
# filling voxel_17_4_1
# voxel filling took 6.666614770889282 seconds ---
# filling voxel_18_4_1
# voxel filling took 6.703391790390015 seconds ---
# filling voxel_19_4_1
# voxel filling took 6.737729549407959 seconds ---
# filling voxel_0_5_1
# voxel filling took 6.619581699371338 seconds ---
# filling voxel_1_5_1
# voxel filling took 6.62705659866333 seconds ---
# filling voxel_2_5_1
# voxel filling took 6.678257465362549 seconds ---
# filling voxel_3_5_1
# voxel filling took 6.721219062805176 seconds ---
# filling voxel_4_5_1
# voxel filling took 6.732217788696289 seconds ---
# filling voxel_5_5_1
# voxel filling took 6.783085584640503 seconds ---
# filling voxel_6_5_1
# voxel filling took 6.925221681594849 seconds ---
# filling voxel_7_5_1
# voxel filling took 6.228966236114502 seconds ---
# filling voxel_8_5_1
# voxel filling took 6.145554065704346 seconds ---
# filling voxel_9_5_1
# voxel filling took 6.190713405609131 seconds ---
# filling voxel_10_5_1
# voxel filling took 6.24319863319397 seconds ---
# filling voxel_11_5_1
# voxel filling took 6.2992844581604 seconds ---
# filling voxel_12_5_1
# voxel filling took 6.3458850383758545 seconds ---
# filling voxel_13_5_1
# voxel filling took 6.4422032833099365 seconds ---
# filling voxel_14_5_1
# voxel filling took 6.4992780685424805 seconds ---
# filling voxel_15_5_1
# voxel filling took 6.403938293457031 seconds ---
# filling voxel_16_5_1
# voxel filling took 6.406924486160278 seconds ---
# filling voxel_17_5_1
# voxel filling took 6.53455662727356 seconds ---
# filling voxel_18_5_1
# voxel filling took 6.608061790466309 seconds ---
# filling voxel_19_5_1
# voxel filling took 6.477171421051025 seconds ---
# filling voxel_0_6_1
# voxel filling took 6.450547456741333 seconds ---
# filling voxel_1_6_1
# voxel filling took 6.6956586837768555 seconds ---
# filling voxel_2_6_1
# voxel filling took 6.576360464096069 seconds ---
# filling voxel_3_6_1
# voxel filling took 6.476171255111694 seconds ---
# filling voxel_4_6_1
# voxel filling took 6.329339981079102 seconds ---
# filling voxel_5_6_1
# voxel filling took 6.250988245010376 seconds ---
# filling voxel_6_6_1
# voxel filling took 6.3370749950408936 seconds ---
# filling voxel_7_6_1
# voxel filling took 6.428545951843262 seconds ---
# filling voxel_8_6_1
# voxel filling took 6.413644552230835 seconds ---
# filling voxel_9_6_1
# voxel filling took 6.444775104522705 seconds ---
# filling voxel_10_6_1
# voxel filling took 6.462272882461548 seconds ---
# filling voxel_11_6_1
# voxel filling took 6.426719427108765 seconds ---
# filling voxel_12_6_1
# voxel filling took 6.303966522216797 seconds ---
# filling voxel_13_6_1
# voxel filling took 6.401535272598267 seconds ---
# filling voxel_14_6_1
# voxel filling took 6.4172279834747314 seconds ---
# filling voxel_15_6_1
# voxel filling took 6.441838264465332 seconds ---
# filling voxel_16_6_1
# voxel filling took 6.446183204650879 seconds ---
# filling voxel_17_6_1
# voxel filling took 6.489123106002808 seconds ---
# filling voxel_18_6_1
# voxel filling took 6.563956260681152 seconds ---
# filling voxel_19_6_1
# voxel filling took 6.499703884124756 seconds ---
# filling voxel_0_7_1
# voxel filling took 6.302400827407837 seconds ---
# filling voxel_1_7_1
# voxel filling took 6.207739353179932 seconds ---
# filling voxel_2_7_1
# voxel filling took 6.154819011688232 seconds ---
# filling voxel_3_7_1
# voxel filling took 6.138449192047119 seconds ---
# filling voxel_4_7_1
# voxel filling took 6.06103515625 seconds ---
# filling voxel_5_7_1
# voxel filling took 6.020564317703247 seconds ---
# filling voxel_6_7_1
# voxel filling took 6.003814220428467 seconds ---
# filling voxel_7_7_1
# voxel filling took 6.006969690322876 seconds ---
# filling voxel_8_7_1
# voxel filling took 6.123216390609741 seconds ---
# filling voxel_9_7_1
# voxel filling took 6.177334308624268 seconds ---
# filling voxel_10_7_1
# voxel filling took 6.233995676040649 seconds ---
# filling voxel_11_7_1
# voxel filling took 6.283596038818359 seconds ---
# filling voxel_12_7_1
# voxel filling took 6.367016077041626 seconds ---
# filling voxel_13_7_1
# voxel filling took 6.443683385848999 seconds ---
# filling voxel_14_7_1
# voxel filling took 6.3968024253845215 seconds ---
# filling voxel_15_7_1
# voxel filling took 6.251083135604858 seconds ---
# filling voxel_16_7_1
# voxel filling took 6.204573392868042 seconds ---
# filling voxel_17_7_1
# voxel filling took 6.143521785736084 seconds ---
# filling voxel_18_7_1
# voxel filling took 6.210627317428589 seconds ---
# filling voxel_19_7_1
# voxel filling took 6.287305593490601 seconds ---
# filling voxel_0_8_1
# voxel filling took 6.361944675445557 seconds ---
# filling voxel_1_8_1
# voxel filling took 6.379941463470459 seconds ---
# filling voxel_2_8_1
# voxel filling took 6.406542778015137 seconds ---
# filling voxel_3_8_1
# voxel filling took 6.37431526184082 seconds ---
# filling voxel_4_8_1
# voxel filling took 6.336379051208496 seconds ---
# filling voxel_5_8_1
# voxel filling took 6.614657878875732 seconds ---
# filling voxel_6_8_1
# voxel filling took 6.875067710876465 seconds ---
# filling voxel_7_8_1
# voxel filling took 6.993113994598389 seconds ---
# filling voxel_8_8_1
# voxel filling took 7.439715623855591 seconds ---
# filling voxel_9_8_1
# voxel filling took 7.529574632644653 seconds ---
# filling voxel_10_8_1
# voxel filling took 7.615542650222778 seconds ---
# filling voxel_11_8_1
# voxel filling took 9.753199338912964 seconds ---
# filling voxel_12_8_1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-8e53b08df569> in <module>
#       8         #print('n_vox_x_init: '+ str(n_vox_x_init))
#       9             start_time = time.time()
# ---> 10             voxel_df = df_final[(df_final['x'] >= voxel_size*num_voxels_x ) & (df_final['x'] < voxel_size*(num_voxels_x+1)) & (df_final['y'] >= voxel_size*num_voxels_y) & (df_final['y'] < voxel_size*(num_voxels_y+1))]
#      11
#      12             with h5py.File('/home/jan/Documents/Voxel_Erstellung/HDFs/voxel_new_filling_method.hdf5', "a") as voxel_hdf:
#
# ~/anaconda3/envs/TDMS_env/lib/python3.7/site-packages/pandas/core/ops/__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~/anaconda3/envs/TDMS_env/lib/python3.7/site-packages/pandas/core/ops/__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# ~/anaconda3/envs/TDMS_env/lib/python3.7/site-packages/pandas/core/ops/__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# -> 1069         result = libops.scalar_compare(x, y, op)
#    1070     return result
#    1071
#
# KeyboardInterrupt:
